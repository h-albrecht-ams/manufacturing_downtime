# %% [markdown]
# Soda bottling production line
#
# The dataset consists of 4 Tables:
# - productivity - what was when produced
# - downtime - what happend, error factor 1 to 12, and duration
# - product - list of products being produced
# - downtime errors - list of downtime factors
#
# Steps taken:
# - tables and content analyzed,  which data and in which format is contained
# - import of data into dataframes
# - renamed the downtime table from factors 1 to 12 with the names of the factors, out of the downtime errors table
#
#
# Questions to answer:
# 1. line efficiency (N)
# 2. operators underperforming (H)
# 3. leading factors for downtime (N)
# 4. Operators struggling with particular types of operator error (H)

# %% [markdown]
# ## Question 1: What Is the Current Line Efficiency? (N)
# - I have calculated, first the total downtimes per batch, and then by grouping by product I have calculated the avg, differentiating between human and machine errors. The diagram shows both, bars as avg. numbers and then the %, which are more meaningful.
#
# ![alt text](image.png)
#
# Finally, I have compared the downtimes to the actual processing time to calculate the efficiency per line
#
# ![image.png](attachment:image.png)
#
# Result: 5 lines have an efficiency above 60% and one lies below.
# --> I would suggest to improve the lines efficiency.

# %% [markdown]
# ## Question 2: Are any operators underperforming (H)

# %% [markdown]
# ![avg_downtime_operator.png](attachment:avg_downtime_operator.png)
#
# ![avg_number_events_operator.png](attachment:avg_number_events_operator.png)

# %% [markdown]
# Based on average downtime per batch, Mac shows the highest observed downtime at 41.5 minutes per batch, followed by Dennis at 37.75 minutes.
#
# Charlie recorded the highest total downtime overall, but also handled more batches, making average downtime the fairer comparison metric.
#
# An additional analysis of downtime frequency showed that Dee experienced the highest average number of downtime events per batch, suggesting more frequent but shorter interruptions.
#
# Overall, operators show different downtime patterns rather than one single clearly weakest performer.

# %% [markdown]
# ## Question 3: What are the leading factors for downtime (N)
# For this I had a look at the following two points:
# - Frequency — which happens more often?
#
# ![image.png](attachment:image.png)
#
# - Severity — which causes longer downtime per incident?
# As the frequency may not tell the right story, I have calculated which is the more severe.
#
# ![image-2.png](attachment:image-2.png)
#
# This is: machine adjustment, which causes also the max. downtimes.

# %% [markdown]
# ## Question 4: Are operators struggling with particular types of operator error (H)

# %% [markdown]
# ![heatmap operator downtime.png](<attachment:heatmap operator downtime.png>)

# %% [markdown]
# The operator error analysis shows clear operator-specific patterns. Mac records high downtime related to batch changes, while Dennis and Charlie show elevated machine adjustment downtime. Dee shows a more balanced distribution of smaller issues. This suggests targeted training may be more effective than a general intervention.

# %% [markdown]
# Conclusions:
# Based on the analysis performed, the most important aspects to take into consideration for improving the company´s and employees efficiency are:
#
# - improve operators´efficiency by training
# - improve machine reliability
# - improve logistics for avoiding inventory bottle necks.
